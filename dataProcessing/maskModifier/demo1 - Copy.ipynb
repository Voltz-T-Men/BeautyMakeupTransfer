# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage
import os

# %%
# plotting 2 image for comparision

mySegImg = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\001.png')
ganSegImg = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\GANMask.png')

cv2.imshow(f"mySegImg:{mySegImg.shape}",mySegImg)
cv2.imshow(f"ganSegImg: {ganSegImg.shape}",ganSegImg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# For resizing seg img
folder_path = r"D:\Project\DPL302m\faceSegmantation\maskModifier\seg\non_makeup"
png_files = [file for file in os.listdir(folder_path) if file.endswith('.png')]
for i, png_file in enumerate(png_files, start=1):
    # Specify the new width and height
    mySegImg = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\seg\non_makeup'+f"\{png_file}")
    new_width = 321
    new_height = 321

    resized_mySegImg = cv2.resize(mySegImg, (new_width, new_height))

    cv2.imwrite(r'D:\Project\DPL302m\faceSegmantation\maskModifier\seg_resized\non_makeup'+f"\{png_file}", resized_mySegImg)
    # cv2.imshow(f"mySegImg:{resized_mySegImg.shape}", resized_mySegImg)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()

# %%
# for gray_scale
cv2_image_masked = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\seg_final\non_makeup\067.png')
gray_image_mask = cv2.cvtColor(cv2_image_masked, cv2.COLOR_BGR2GRAY)
copy_plt_image = gray_image_mask
for j in range(0,320):
    for k in range(0,320):
        if copy_plt_image[j,k] == 13:
            copy_plt_image[j,k] = 255
plt.imshow(copy_plt_image)

# %%
ganSegImg = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\GANMask.png')
# copy_plt_image = cv2_image_masked*255
# For gray_scale
channel_value = {}
channel_value = set()
channel_value2 = []
for j in range(0,320):
    for k in range(0,320):
        element = gray_image_mask[j,k]
        channel_value.add(element)
print(channel_value)
print(len(channel_value))
# for i in channel_value:
#     channel_value2.append(i*17)
# print(channel_value2)
# plt.imshow(copy_plt_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 for j in range(0,320):
#       8     for k in range(0,320):
# ----> 9         element = gray_image_mask[j,k]
#      10         channel_value.add(element)
#      11 print(channel_value)
#
# NameError: name 'gray_image_mask' is not defined

# %%
cv2.imwrite('copy_plt_image.png',copy_plt_image)
# Out:
# True

# %%
gray_image_mask = cv2.cvtColor(cv2_image_masked, cv2.COLOR_BGR2GRAY)
# gray_image_mask.shape

cv2.imshow(f"original :{cv2_image_orig.shape}",cv2_image_orig)
cv2.imshow(f"masked: {cv2_image_masked.shape}",cv2_image_masked)
cv2.imshow(f"gray_masked: {gray_image_mask.shape}",gray_image_mask)
# cv2.imshow(f"original",cv2_image_orig)
# cv2.imshow(f"masked",cv2_image_masked)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# gray_image_mask.shape
copy_image = gray_image_mask*1

plt.imshow(copy_plt_image)

# %%
# for gray_scale
copy_image = gray_image_mask*1
for j in range(0,360):
    for k in range(0,360):
        if copy_image[j,k] == 128:
            copy_image[j,k] = 0
plt.imshow(copy_image)

# %%
# For gray_scale
cv2_image_masked = cv2.imread(r'D:\Project\DPL302m\faceSegmantation\maskModifier\seg_final\non_makeup\067.png')
gray_image_mask = cv2.cvtColor(cv2_image_masked, cv2.COLOR_BGR2GRAY)
channel_value = {}
channel_value = set()
channel_value2 = []
for j in range(0,360):
    for k in range(0,360):
        element = gray_image_mask[j,k]
        channel_value.add(element)
print(channel_value)
# for i in channel_value:
#     channel_value2.append(i*17)
# print(channel_value2)
# plt.imshow(copy_plt_image)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 9, 10, 12, 13, 86}

# %%
# for 3 channel
copy_plt_image = plt_image*17
for i in range(0,2):
    for j in range(0,320):
        for k in range(0,320):
            if copy_plt_image[j,k,i] == 128:
                copy_plt_image[j,k,i] = 0
plt.imshow(copy_plt_image)

# %%
# for 3 channel
channel_value = {}
channel_value = set()
channel_value2 = []
for i in range(0,2):
    for j in range(0,360):
        for k in range(0,360):
            element = copy_image[j,k,i]
            channel_value.add(element)
print(channel_value)
for i in channel_value:
    channel_value2.append(i*17)
print(channel_value2)
# plt.imshow(copy_plt_image)
